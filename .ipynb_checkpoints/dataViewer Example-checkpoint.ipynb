# %% [markdown]
# # Import Functions / Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import rc
rc('animation', html='html5')

#import viewer functions
from dataViewer import plotTraj, animatePreview, animateLoc, animateTraj

# %matplotlib inline

# %% [markdown]
# # Load Dataset

# %%
# Deutsche uni

# Dataset Information
# 
# Frame rate: 16 FPS
#
# Person id | frame | x pos | y pos | z pos

FPS = 16
BG = "Datasets/UG/ug.png"
PATH_1 = "Datasets/UG/UG-roh_nachkorrigiert/ug-100-007.txt"

# %%
class DataLoader():
    def __init__(self, path, x_o=0, y_o=0):
        self.path = path
        self.x_offset = x_o
        self.y_offset = y_o
        with open(path) as f:
            df = pd.DataFrame(columns=['p', 'f', 'x', 'y', 'z'] )
            for line in f:
                data = [float(d) for d in line.strip().split()]
                df = df.append( dict( zip(df.columns, data) ), ignore_index=True )
                
        self.data = df 
        
    
    def person(self, id):
        self.temp = self.data[self.data['p'] == id]
        
        l = len(self.temp)
        cor = np.vstack((np.ones(l)*-1, np.ones(l))).T
        offset = np.vstack((np.ones(l)*self.x_offset, np.ones(l)*self.y_offset)).T
        return self.temp['f'].to_numpy(), self.temp[['y', 'x']].to_numpy() * cor+offset
    
    
    def frame(self, id):
        self.temp = self.data[self.data['f'] == id]
        l = len(self.temp)
        cor = np.vstack((np.ones(l)*-1, np.ones(l))).T
        offset = np.vstack((np.ones(l)*self.x_offset, np.ones(l)*self.y_offset)).T
        return self.temp['p'].to_numpy(), self.temp[['y', 'x']].to_numpy() * cor+offset
    
    def __len__(self):
        return int(self.data['f'].max() - self.data['f'].min())

# %%
loader_1 = DataLoader(PATH_1)

# %% [markdown]
# # Plot Trajectories

# %%
plotTraj(loader_1, boundaries=[-600, 600, -250, 150], people=[1,10,16], legend=False, title="Trajectories 1,2,3", save=False)

# %% [markdown]
# # Animate Location / Trajectories

# %%
animatePreview(loader_1, boundaries=[600, -600, -250, 150], step=10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-dc2147cd5a89> in <module>
# ----> 1 animatePreview(loader_1, boundaries=[600, -600, -250, 150], step=10)
#
# ~/CNN/Projects/ai-team/dataViewer.py in animatePreview(loader, boundaries, step)
#     213         step:       frame-step from one image to the next (step=1 means all frames are plotted, step=5 everey 5th)
#     214         """
# --> 215     import plotly.express as px
#     216     fig = px.scatter(loader.data[(loader.data['f'] % 10) == 0],
#     217            x="y", y="x",
#
# ModuleNotFoundError: No module named 'plotly'

# %%
ani = animateLoc(loader_1, frame_start=0, frame_stop=len(loader_1), boundaries=[-600, 600, -250, 150], step=5, fps=16, title="ululululu")
ani
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     160         try:
# --> 161             return self.avail[name]
#     162         except KeyError:
#
# KeyError: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _repr_html_(self)
#    1387         fmt = rcParams['animation.html']
#    1388         if fmt == 'html5':
# -> 1389             return self.to_html5_video()
#    1390         elif fmt == 'jshtml':
#    1391             return self.to_jshtml()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1324                 # We create a writer manually so that we can get the
#    1325                 # appropriate size for the tag
# -> 1326                 Writer = writers[rcParams['animation.writer']]
#    1327                 writer = Writer(codec='h264',
#    1328                                 bitrate=rcParams['animation.bitrate'],
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     162         except KeyError:
#     163             raise RuntimeError(
# --> 164                 'Requested MovieWriter ({}) not available'.format(name))
#     165
#     166
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %%
ani = animateTraj(loader_1, frame_start=500, frame_stop=800, boundaries=[-600, 600, -250, 150], step=5, fps=16, title="Trajectory Animation")
ani
# Out:
# <video width="720" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...
